# %% [markdown]
# <a href="https://colab.research.google.com/github/ryali93/SupportGIS/blob/master/arbol_navidad.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
import matplotlib.pyplot as plt
from math import exp,sin,cos
from pylab import *
import random

tree_color = '#28cf75'
star_color = '#fdfce3'
star_color_edge = '#fce97f'
back_color = '#272822'
orn_color_a = '#16b8f7'
orn_color_b = '#f77d7c'
orn_color_c = '#fcfee2'

christmas_tree_path = 'christmas_tree.jpg'

fig = plt.figure()
ax = fig.gca(projection='3d')
a, b = 0.01, 0.02

th = np.linspace(0, 150, 10000)  
x = a * exp(b * th) * cos(th)
y = a * exp(b * th) * sin(th)
z = -1 * np.linspace(0, 2, 10000)

ax.plot(x, y, z, color=tree_color)

cf = random.choice(range(200, 400))
ax.scatter(x[::cf], y[::cf], z[::cf], s=35, alpha=0.9, color=orn_color_a)

bf = random.choice(range(100, 200))
ax.scatter(x[::bf], y[::bf], z[::bf], s=30, alpha=0.9, color=orn_color_b)

af = random.choice(range(50, 100))
ax.scatter(x[::af], y[::af], z[::af], s=40, alpha=0.9, color=orn_color_c)

ax.scatter(0, 0, 0.15, alpha=1, c=star_color, s=1050, marker='*', edgecolors=star_color_edge, linewidth=4)

ax.set_axis_off()
ax.set_facecolor(back_color)
fig.patch.set_facecolor('w')
fig.set_size_inches(10, 10, forward=True)

plt.tight_layout()
plt.savefig(christmas_tree_path)
plt.show()

# %%
# !pip install "stereoscopy"
# Out:
# Collecting stereoscopy
#   Downloading https://files.pythonhosted.org/packages/4c/7a/1325b9d39b38918de6ccd3877a32f2286b55db2ed8f421b7da3d153baa6b/stereoscopy-2.0.1-py3-none-any.whl
# Requirement already satisfied: Pillow in /usr/local/lib/python3.6/dist-packages (from stereoscopy) (7.0.0)
# Installing collected packages: stereoscopy
# Successfully installed stereoscopy-2.0.1

# %%
# !StereoscoPy -A -R 800 0 -S 1 3 -a christmas_tree.jpg christmas_tree.jpg christmas_tree_prod.jpg
