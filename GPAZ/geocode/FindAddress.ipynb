# %% [markdown]
# ## Buscar direcciones con API de geocódigos que usan NLP

# %% [markdown]
# Instalación de API

# %%
# !pip install arcgis

# %% [markdown]
# Importación de librerías

# %%
from arcgis.gis import GIS
from arcgis.geocoding import geocode, reverse_geocode
from arcgis.geometry import Point

# %%
gis = GIS()

# %%
import pandas as pd

# %% [markdown]
# Leyendo archivo del que se consultarán las direcciones

# %%
df = pd.read_csv("direcciones.csv", sep=";", encoding="cp1252")
df.head()
# Out:
#   Campo1  CLIENTE  SERVICIO TIPOVIA                NOMBREVIA PUERTA  PISO  \
# 0    PUN  6661946   5714017      ND                        .      0   NaN
# 1    PUN  6708518   5714051      JR  PORRAS BARRENECHEA RAUL    219   NaN
# 2    PUN  6711806   5799021     NaN           TUPAC YUPANQUI      0   NaN
# 3    PUN  6740184   5821315      JR             VILQUE CHICO    415   NaN
# 4    PUN  6740202   5821277      JR              24 DE JUNIO    124   NaN
#
#     MZ LOTE DISTRITO  ...   TAP BORNE     Campo31   Campo32    Campo33  \
# 0    C   10  JULIACA  ...   9.0   1.0   8/03/2017  09:32:58  7507925.0
# 1  NaN  NaN  JULIACA  ...   3.0   1.0  21/03/2017  18:31:39  7507926.0
# 2  H12    8  JULIACA  ...  10.0   1.0  22/03/2017  18:25:57  7608640.0
# 3  NaN  NaN  JULIACA  ...  14.0   1.0  30/03/2017  15:51:03  7635893.0
# 4  NaN  NaN  JULIACA  ...   7.0   1.0  30/03/2017  15:56:03  7634846.0
#
#    Campo34  Campo35  ID  PAIS DEPARTAMENTO
# 0        S     G003   1  PERÚ         PUNO
# 1        S     G003   2  PERÚ         PUNO
# 2        S     G003   3  PERÚ         PUNO
# 3        S     G003   4  PERÚ         PUNO
# 4        S     G003   5  PERÚ         PUNO
#
# [5 rows x 32 columns]

# %% [markdown]
# Evaluando la dirección y creando campos

# %%
# df["ADDRESS"] = df["DIRECCION"].apply(lambda x: x + ", Puno, PER")
df["ADDRESS"] = df["DIRECCION"].apply(lambda x: x.replace("PERÚ", "PER"))
# df["ADDRESS"] = df["DIRECCION"]
df["x"] = 0
df["y"] = 0
df["Match_addr"] = ""
df["Score"] = ""

# %%
df.head()
# Out:
#   Campo1  CLIENTE  SERVICIO TIPOVIA                NOMBREVIA PUERTA  PISO  \
# 0    PUN  6661946   5714017      ND                        .      0   NaN
# 1    PUN  6708518   5714051      JR  PORRAS BARRENECHEA RAUL    219   NaN
# 2    PUN  6711806   5799021     NaN           TUPAC YUPANQUI      0   NaN
# 3    PUN  6740184   5821315      JR             VILQUE CHICO    415   NaN
# 4    PUN  6740202   5821277      JR              24 DE JUNIO    124   NaN
#
#     MZ LOTE DISTRITO  ... Campo34 Campo35 ID  PAIS  DEPARTAMENTO  \
# 0    C   10  JULIACA  ...       S    G003  1  PERÚ          PUNO
# 1  NaN  NaN  JULIACA  ...       S    G003  2  PERÚ          PUNO
# 2  H12    8  JULIACA  ...       S    G003  3  PERÚ          PUNO
# 3  NaN  NaN  JULIACA  ...       S    G003  4  PERÚ          PUNO
# 4  NaN  NaN  JULIACA  ...       S    G003  5  PERÚ          PUNO
#
#                                         ADDRESS  x  y Match_addr Score
# 0      MZ C LOTE 10, UR RINCONADA, JULIACA, PER  0  0
# 1  JR PORRAS BARRENECHEA RAUL 219, JULIACA, PER  0  0
# 2  MZ H12 LOTE 8, MUN. LA CAPILLA, JULIACA, PER  0  0
# 3             JR VILQUE CHICO 415, JULIACA, PER  0  0
# 4              JR 24 DE JUNIO 124, JULIACA, PER  0  0
#
# [5 rows x 37 columns]

# %% [markdown]
# Definiendo una función de consulta e inserción de elementos a partir de la dirección buscada

# %%
def extractAddress(df, indice, idDf, address):
    gis = GIS()
    geocode_result = geocode(address = df.iloc[indice][address], as_featureset=True, max_locations=3) # Cambiar la dirección
    for x in geocode_result.features:
        gdpoint = x.as_dict["geometry"]
        attr = x.as_dict["attributes"]
        df = df.append(pd.Series([df.iloc[indice][idDf], gdpoint["x"], gdpoint["y"], attr["Match_addr"], attr["Score"]], index=["CLIENTE", "x", "y", "Match_addr", "Score"] ), ignore_index=True)
    return df

# %% [markdown]
# Ejecutando la función para los primeros 50 elementos

# %%
# for n in range(len(df)):
for n in range(50):
    if n%10==0: print(n)
    df = extractAddress(df, n, "CLIENTE", "ADDRESS")
# Out:
# 0
# 10
# 20
# 30
# 40

# %% [markdown]
# Visualizando resultados por cada CLIENTE

# %%
df=df.sort_values(by='CLIENTE')
df.head()
# Out:
#       Campo1  CLIENTE   SERVICIO TIPOVIA                NOMBREVIA PUERTA  \
# 0        PUN  6661946  5714017.0      ND                        .      0
# 18301    NaN  6661946        NaN     NaN                      NaN    NaN
# 18300    NaN  6661946        NaN     NaN                      NaN    NaN
# 18299    NaN  6661946        NaN     NaN                      NaN    NaN
# 1        PUN  6708518  5714051.0      JR  PORRAS BARRENECHEA RAUL    219
#
#        PISO   MZ LOTE DISTRITO  ... Campo34 Campo35   ID  PAIS  DEPARTAMENTO  \
# 0       NaN    C   10  JULIACA  ...       S    G003  1.0  PERÚ          PUNO
# 18301   NaN  NaN  NaN      NaN  ...     NaN     NaN  NaN   NaN           NaN
# 18300   NaN  NaN  NaN      NaN  ...     NaN     NaN  NaN   NaN           NaN
# 18299   NaN  NaN  NaN      NaN  ...     NaN     NaN  NaN   NaN           NaN
# 1       NaN  NaN  NaN  JULIACA  ...       S    G003  2.0  PERÚ          PUNO
#
#                                             ADDRESS          x          y  \
# 0          MZ C LOTE 10, UR RINCONADA, JULIACA, PER   0.000000   0.000000
# 18301                                           NaN -77.733330 -10.416670
# 18300                                           NaN -77.400830  -8.147220
# 18299                                           NaN -70.141062 -15.505383
# 1      JR PORRAS BARRENECHEA RAUL 219, JULIACA, PER   0.000000   0.000000
#
#                                               Match_addr  Score
# 0
# 18301                          Rinconada, Barranca, Lima  78.67
# 18300         Rinconada, Provincia de Pataz, La Libertad  78.67
# 18299  Avenida La Rinconada, Juliaca, San Román, Puno...  82.91
# 1
#
# [5 rows x 37 columns]

# %% [markdown]
# Exportando resultados a formato excel

# %%
df.to_excel("resultado.xls")
